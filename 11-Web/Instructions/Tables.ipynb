# %%
import pandas as pd
import datetime

# %%
filepath = r'../Instructions/Resources/cities.csv'
df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#          City Country  Latitude  Longitude  Wind Speed (mph)  \
# 0  georgetown      MY      5.41     100.34              5.57
# 1       kapaa      US     22.08    -159.32             17.22
# 2     rikitea      PF    -23.12    -134.97             15.14
# 3       bilma      NE     18.69      12.92             14.36
# 4      barrow      US     71.29    -156.79              9.17
#
#    Temperature (Fahrenheit)  Humidity  Visibility  Pressure
# 0                     80.11        94          20      1010
# 1                     78.53        69          75      1022
# 2                     73.89        73         100      1016
# 3                     84.92        12           0      1009
# 4                     12.20        85           1      1025

# %%
df.Date = df.Date.apply(lambda x:datetime.datetime.fromtimestamp(x).strftime(""))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-fd1b7c1893b9> in <module>
# ----> 1 df.Date = df.Date.apply(lambda x:datetime.datetime.fromtimestamp(x).strftime(""))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df.head()

# %%
print(df.to_html(index = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Wind Speed (mph)</th>
#       <th>Temperature (Fahrenheit)</th>
#       <th>Humidity</th>
#       <th>Visibility</th>
#       <th>Pressure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>georgetown</td>
#       <td>MY</td>
#       <td>5.41</td>
#       <td>100.34</td>
#       <td>5.57</td>
#       <td>80.11</td>
#       <td>94</td>
#       <td>20</td>
#       <td>1010</td>
#     </tr>
#     <tr>
#       <td>kapaa</td>
#       <td>US</td>
#       <td>22.08</td>
#       <td>-159.32</td>
#       <td>17.22</td>
#       <td>78.53</td>
#       <td>69</td>
#       <td>75</td>
#       <td>1022</td>
#     </tr>
#     <tr>
#       <td>rikitea</td>
#       <td>PF</td>
#       <td>-23.12</td>
#       <td>-134.97</td>
#       <td>15.14</td>
#       <td>73.89</td>
#       <td>73</td>
# ...
