# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = r"purchase_data.csv"
# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

purchase_data.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44
# 5                                  Dreamkiss   3.61
# 6     Interrogator, Blood Blade of the Queen   2.18
# 7                              Abyssal Shard   2.67
# 8                                  Souleater   1.10
# 9               Ghastly Adamantite Protector   3.58

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
player_count = len(purchase_data["SN"].unique())
player_count
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#total number of unique items
item_count = len(purchase_data["Item Name"].unique())
item_count
# Out:
# 179

# %%
#average price of items
avg_price = round(purchase_data['Price'].mean(),2)
avg_price
# Out:
# 3.05

# %%
#total number of purchases
purchase_count = len(purchase_data['Purchase ID'])
purchase_count
# Out:
# 780

# %%
#total revenue
total_rev = round(purchase_data['Price'].sum(),2)
total_rev
# Out:
# 2379.77

# %%
purchasing_df = pd.DataFrame({"Total Players": [player_count],
             "Item Count": [item_count],
             "Average Price": [avg_price],
             "Total Purchases": [purchase_count],
             "Total Revenues": [total_rev],})
purchasing_df
# Out:
#    Total Players  Item Count  Average Price  Total Purchases  Total Revenues
# 0            576         179           3.05              780         2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_sort = purchase_data.groupby("Gender")

gender_sort.count()
# Out:
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
gender_count = gender_sort.nunique()["SN"]
gender_count
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
gender_percent = gender_count.apply(lambda x: (x/player_count)*100)
gender_percent
# Out:
# Gender
# Female                   14.062500
# Male                     84.027778
# Other / Non-Disclosed     1.909722
# Name: SN, dtype: float64

# %%
pd.concat([gender_count,gender_percent],axis = 1)
# Out:
#                         SN         SN
# Gender
# Female                  81  14.062500
# Male                   484  84.027778
# Other / Non-Disclosed   11   1.909722

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purch_ct_gen = pd.DataFrame(gender_sort['Purchase ID'].count())
purch_ct_gen
# Out:
#                        Purchase ID
# Gender
# Female                         113
# Male                           652
# Other / Non-Disclosed           15

# %%
avg_price_gen = round(pd.DataFrame(gender_sort['Price'].mean()),2)
avg_price_gen
# Out:
#                        Price
# Gender
# Female                  3.20
# Male                    3.02
# Other / Non-Disclosed   3.35

# %%
#average purchase total per person
sum_price = pd.DataFrame(gender_sort['Price'].sum())
sum_price
# Out:
#                          Price
# Gender
# Female                  361.94
# Male                   1967.64
# Other / Non-Disclosed    50.19

# %% [markdown]
# sum_price/gender_count

# %%
#create summary table + format
gender_df = pd.merge(pd.merge(purch_ct_gen,avg_price_gen,on = "Gender"),sum_price,on="Gender",
                     suffixes = ["_Average","_Average Total"])
gender_df
# Out:
#                        Purchase ID  Price_Average  Price_Average Total
# Gender
# Female                         113           3.20               361.94
# Male                           652           3.02              1967.64
# Other / Non-Disclosed           15           3.35                50.19

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# purchase_data.Age.max()
# purchase_data.Age.min()
# #bins should be from 5 to 50

# %%
bins = [5,14,23,32,41,50]
labels = ['5-14','15-23','24-32','33-41','42-50']
age_int = pd.cut(purchase_data.Age,bins, labels = labels)
age_int
# Out:
# 0      15-23
# 1      33-41
# 2      24-32
# 3      24-32
# 4      15-23
#        ...
# 775    15-23
# 776    15-23
# 777    15-23
# 778     5-14
# 779    24-32
# Name: Age, Length: 780, dtype: category
# Categories (5, object): [5-14 < 15-23 < 24-32 < 33-41 < 42-50]

# %%
bins_ct = age_int.value_counts()
bins_ct
# Out:
# 15-23    434
# 24-32    218
# 33-41     72
# 5-14      51
# 42-50      5
# Name: Age, dtype: int64

# %%
bins_pct = round(bins_ct.apply(lambda x: (x)/player_count)*100,2)
bins_pct
# Out:
# 15-23    75.35
# 24-32    37.85
# 33-41    12.50
# 5-14      8.85
# 42-50     0.87
# Name: Age, dtype: float64

# %%
#create summary table
# age_summary = pd.concat([bins_ct,bins_pct],axis=1,sort=True)

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
age_sort = purchase_data.assign(Ages = age_int)
age_sort.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price   Ages
# 0  Extraction, Quickblade Of Trembling Hands   3.53  15-23
# 1                          Frenzied Scimitar   1.56  33-41
# 2                               Final Critic   4.88  24-32
# 3                                Blindscythe   3.27  24-32
# 4                                       Fury   1.44  15-23

# %%
purch_ct_age = age_sort.groupby('Ages')['Purchase ID'].count()
purch_ct_age
# Out:
# Ages
# 5-14      51
# 15-23    434
# 24-32    218
# 33-41     72
# 42-50      5
# Name: Purchase ID, dtype: int64

# %%
avg_price_age = round(age_sort.groupby('Ages')['Price'].mean(),2)
avg_price_age
# Out:
# Ages
# 5-14     3.14
# 15-23    3.03
# 24-32    3.03
# 33-41    3.16
# 42-50    3.00
# Name: Price, dtype: float64

# %%
sum_price_age = age_sort.groupby('Ages')['Price'].sum()
sum_price_age
# Out:
# Ages
# 5-14      159.91
# 15-23    1316.73
# 24-32     660.28
# 33-41     227.86
# 42-50      14.99
# Name: Price, dtype: float64

# %%
pd.concat([purch_ct_age,avg_price_age,sum_price_age], axis = 1)
# Out:
#        Purchase ID  Price    Price
# Ages
# 5-14            51   3.14   159.91
# 15-23          434   3.03  1316.73
# 24-32          218   3.03   660.28
# 33-41           72   3.16   227.86
# 42-50            5   3.00    14.99

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
temp = purchase_data[['SN','Price']].groupby('SN').sum().sort_values('Price', ascending = False).head(5)
mask = list(temp.index)

# %%
purchase_data_new = purchase_data.set_index('SN')
purchase_data_new

spender_data = purchase_data_new.loc[mask]
spender_data
# Out:
#              Purchase ID  Age  Gender  Item ID  \
# SN
# Lisosia93             74   25    Male       89
# Lisosia93            120   25    Male       24
# Lisosia93            224   25    Male      157
# Lisosia93            603   25    Male      132
# Lisosia93            609   25    Male       40
# Idastidru52          290   24    Male      147
# Idastidru52          490   24    Male      148
# Idastidru52          543   24    Male      121
# Idastidru52          676   24    Male      111
# Chamjask73           222   22  Female      178
# Chamjask73           520   22  Female      109
# Chamjask73           564   22  Female       52
# Iral74               128   21    Male       58
# Iral74               623   21    Male      114
# Iral74               758   21    Male      182
# Iral74               776   21    Male      164
# Iskadarya95          148   20    Male      148
# Iskadarya95          247   20    Male       82
# Iskadarya95          318   20    Male       91
#
#                                                 Item Name  Price
# SN
# Lisosia93               Blazefury, Protector of Delusions   4.64
# Lisosia93                                   Warped Fetish   3.81
# Lisosia93                         Spada, Etcher of Hatred   4.80
# Lisosia93                                      Persuasion   3.19
# Lisosia93                                   Second Chance   2.52
# Idastidru52             Hellreaver, Heirloom of Inception   4.93
# Idastidru52            Warmonger, Gift of Suffering's End   4.03
# Idastidru52                                      Massacre   1.60
# Idastidru52                                  Misery's End   4.89
# Chamjask73   Oathbreaker, Last Hope of the Breaking Storm   4.23
# Chamjask73               Downfall, Scalpel Of The Emperor   4.76
# Chamjask73                                         Hatred   4.84
# Iral74                  Freak's Bite, Favor of Holy Might   4.14
# Iral74                                 Yearning Mageblade   3.82
# Iral74                                          Toothpick   4.03
# Iral74                                   Exiled Doomblade   1.63
# Iskadarya95            Warmonger, Gift of Suffering's End   4.03
# Iskadarya95                                       Nirvana   4.90
# Iskadarya95                                       Celeste   4.17

# %%
purch_ct_spend = spender_data.groupby('SN')['Purchase ID'].count()
purch_ct_spend
# Out:
# SN
# Chamjask73     3
# Idastidru52    4
# Iral74         4
# Iskadarya95    3
# Lisosia93      5
# Name: Purchase ID, dtype: int64

# %%
avg_price_spend = round(spender_data.groupby('SN')['Price'].mean(),2)
avg_price_spend
# Out:
# SN
# Chamjask73     4.61
# Idastidru52    3.86
# Iral74         3.40
# Iskadarya95    4.37
# Lisosia93      3.79
# Name: Price, dtype: float64

# %%
purch_sum_spend = spender_data.groupby('SN')['Price'].sum()
purch_sum_spend
# Out:
# SN
# Chamjask73     13.83
# Idastidru52    15.45
# Iral74         13.62
# Iskadarya95    13.10
# Lisosia93      18.96
# Name: Price, dtype: float64

# %%
#summary table

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
temp2 = purchase_data[['Item ID','Item Name','Price']].groupby('Item Name').sum().sort_values('Price', ascending = False).head(5)
mask2 = list(temp2.index)
item_data = purchase_data.set_index('Item Name').loc[mask2]
item_data
# Out:
#                                               Purchase ID              SN  \
# Item Name
# Final Critic                                            2      Ithergue48
# Final Critic                                           99    Haisrisuir60
# Final Critic                                          252        Tyaelo67
# Final Critic                                          273        Phyali88
# Final Critic                                          277      Ennalmol65
# Final Critic                                          411        Lisico81
# Final Critic                                          536     Siallylis44
# Final Critic                                          712       Lisilsa62
# Final Critic                                          722        Ilarin91
# Final Critic                                          767         Ilmol66
# Final Critic                                          768    Assassasta79
# Final Critic                                          774      Jiskjask80
# Final Critic                                          778         Sisur91
# Oathbreaker, Last Hope of the Breaking Storm           25       Lisirra87
# Oathbreaker, Last Hope of the Breaking Storm           61      Jiskimya77
# Oathbreaker, Last Hope of the Breaking Storm           62      Yadaphos40
# Oathbreaker, Last Hope of the Breaking Storm           72       Marilsa69
# Oathbreaker, Last Hope of the Breaking Storm          222      Chamjask73
# Oathbreaker, Last Hope of the Breaking Storm          464    Rianistast50
# Oathbreaker, Last Hope of the Breaking Storm          580         Tyida79
# Oathbreaker, Last Hope of the Breaking Storm          627          Arin32
# Oathbreaker, Last Hope of the Breaking Storm          658      Quilassa66
# Oathbreaker, Last Hope of the Breaking Storm          706   Chanossanya44
# Oathbreaker, Last Hope of the Breaking Storm          730       Aidaira26
# Oathbreaker, Last Hope of the Breaking Storm          753  Frichirranya75
# Nirvana                                                18       Reunasu60
# Nirvana                                                88      Laedallo55
# Nirvana                                               202       Phistym51
# Nirvana                                               240    Lirtastsda29
# Nirvana                                               247     Iskadarya95
# Nirvana                                               274   Aerithllora36
# Nirvana                                               504    Chamilsala65
# Nirvana                                               522     Meosridil82
# Nirvana                                               666      Assilsan72
# Fiery Glass Crusader                                  132       Inguron55
# Fiery Glass Crusader                                  207    Sondastsda82
# Fiery Glass Crusader                                  329        Ceoral34
# Fiery Glass Crusader                                  438       Qilunan34
# Fiery Glass Crusader                                  474           Ina92
# Fiery Glass Crusader                                  572   Yoishirrala98
# Fiery Glass Crusader                                  683       Ialallo29
# Fiery Glass Crusader                                  741    Phiallylis33
# Fiery Glass Crusader                                  769       Ilosian36
# Singed Scalpel                                        175        Indcil77
# Singed Scalpel                                        373          Aina42
# Singed Scalpel                                        455     Lisossala30
# Singed Scalpel                                        460    Assistasda90
# Singed Scalpel                                        476       Marassa62
# Singed Scalpel                                        634         Eoral49
# Singed Scalpel                                        660          Isri34
# Singed Scalpel                                        714       Tyidaim51
#
#                                               Age  Gender  Item ID  Price
# Item Name
# Final Critic                                   24    Male       92   4.88
# Final Critic                                   23    Male       92   4.19
# Final Critic                                   39    Male       92   4.88
# Final Critic                                   15  Female       92   4.88
# Final Critic                                   24    Male       92   4.88
# Final Critic                                   10    Male       92   4.19
# Final Critic                                   20    Male       92   4.19
# Final Critic                                   25    Male       92   4.88
# Final Critic                                   22    Male       92   4.88
# Final Critic                                    8  Female       92   4.88
# Final Critic                                   38    Male       92   4.88
# Final Critic                                   11    Male       92   4.19
# Final Critic                                    7    Male       92   4.19
# Oathbreaker, Last Hope of the Breaking Storm   29    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   17    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   30    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   25  Female      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   22  Female      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   22    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   24    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   25    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm    7  Female      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   20    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   30    Male      178   4.23
# Oathbreaker, Last Hope of the Breaking Storm   36    Male      178   4.23
# Nirvana                                        22  Female       82   4.90
# Nirvana                                        30    Male       82   4.90
# Nirvana                                        37    Male       82   4.90
# Nirvana                                        16    Male       82   4.90
# Nirvana                                        20    Male       82   4.90
# Nirvana                                        29  Female       82   4.90
# Nirvana                                        23  Female       82   4.90
# Nirvana                                        18    Male       82   4.90
# Nirvana                                        20  Female       82   4.90
# Fiery Glass Crusader                           23    Male      145   4.58
# Fiery Glass Crusader                           24    Male      145   4.58
# Fiery Glass Crusader                           20    Male      145   4.58
# Fiery Glass Crusader                           23    Male      145   4.58
# Fiery Glass Crusader                           31    Male      145   4.58
# Fiery Glass Crusader                           17  Female      145   4.58
# Fiery Glass Crusader                           15  Female      145   4.58
# Fiery Glass Crusader                           19    Male      145   4.58
# Fiery Glass Crusader                           15    Male      145   4.58
# Singed Scalpel                                 17    Male      103   4.35
# Singed Scalpel                                 25    Male      103   4.35
# Singed Scalpel                                 20    Male      103   4.35
# Singed Scalpel                                 25    Male      103   4.35
# Singed Scalpel                                 21    Male      103   4.35
# Singed Scalpel                                 16    Male      103   4.35
# Singed Scalpel                                 38    Male      103   4.35
# Singed Scalpel                                 16  Female      103   4.35

# %%
purch_ct_item = item_data.groupby('Item Name')['Purchase ID'].count()
purch_ct_item
# Out:
# Item Name
# Fiery Glass Crusader                             9
# Final Critic                                    13
# Nirvana                                          9
# Oathbreaker, Last Hope of the Breaking Storm    12
# Singed Scalpel                                   8
# Name: Purchase ID, dtype: int64

# %%
avg_price_item = round(item_data.groupby('Item Name')['Price'].mean(),2)
avg_price_item
#Took the average price for items instead of pulling price because there are two different prices for Final Critic
# Out:
# Item Name
# Fiery Glass Crusader                            4.58
# Final Critic                                    4.61
# Nirvana                                         4.90
# Oathbreaker, Last Hope of the Breaking Storm    4.23
# Singed Scalpel                                  4.35
# Name: Price, dtype: float64

# %%
purch_sum_item = item_data.groupby('Item Name')['Price'].sum()
purch_sum_item
# Out:
# Item Name
# Fiery Glass Crusader                            41.22
# Final Critic                                    59.99
# Nirvana                                         44.10
# Oathbreaker, Last Hope of the Breaking Storm    50.76
# Singed Scalpel                                  34.80
# Name: Price, dtype: float64

# %%
#summary table

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame
